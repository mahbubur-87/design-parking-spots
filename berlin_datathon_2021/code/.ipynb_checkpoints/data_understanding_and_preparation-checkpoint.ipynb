# %%
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import earthpy as et
import fiona
#fiona.supported_drivers

# %%
os.chdir(os.path.join(et.io.HOME, 'mahbub-dev/beuth_hochschule_for_technik_berlin/berlin_datathon_2021/data'))

# %%
count_parking_spots_estimated_kfz_path = os.path.join("Bezirksamt-20211120T113159Z-001", "Bezirksamt", "parking", "estimated_parking_spots_kfz.geojson")
df_count_parking_spots_estimated_kfz = gpd.read_file(count_parking_spots_estimated_kfz_path)
df_count_parking_spots_estimated_kfz.dtypes
# Out:
# highway                 object
# name                    object
# parking                 object
# orientation             object
# position                object
# capacity                object
# source_orientation      object
# source_position         object
# source_capacity         object
# geometry              geometry
# dtype: object

# %%
df_count_parking_spots_estimated_kfz.head(6)
# Out:
#      highway                          name parking orientation   position  \
# 0  secondary  Platz der Vereinten Nationen    lane    parallel  on_street
# 1  secondary  Platz der Vereinten Nationen    lane    parallel  on_street
# 2  secondary  Platz der Vereinten Nationen    lane    parallel  on_street
# 3  secondary  Platz der Vereinten Nationen    lane    parallel  on_street
# 4  secondary  Platz der Vereinten Nationen    lane    parallel  on_street
# 5   tertiary                   Thaerstraße    lane    parallel  on_street
#
#   capacity source_orientation source_position source_capacity  \
# 0        2          estimated       estimated       estimated
# 1        2          estimated       estimated       estimated
# 2        3          estimated       estimated       estimated
# 3        3          estimated       estimated       estimated
# 4        3          estimated       estimated       estimated
# 5       19          estimated       estimated       estimated
#
#                          geometry
# 0  POINT (393464.636 5820319.350)
# 1  POINT (393465.659 5820324.449)
# 2  POINT (393467.819 5820340.710)
# 3  POINT (393468.221 5820345.894)
# 4  POINT (393468.623 5820351.079)
# 5  POINT (395184.661 5820162.413)

# %%
registered_cars_path = os.path.join("Bezirksamt-20211120T113159Z-001", "Bezirksamt", "demographics", "registered_cars.geojson")
df_registered_cars = gpd.read_file(registered_cars_path)
df_registered_cars = df_registered_cars.rename(columns={"district ": "district"})
df_registered_cars.dtypes
# Out:
# district                           object
# lor                                object
# Bezirksregion                      object
# Prognoseraum                       object
# lor size in m²                    float64
# inhabitants_total                   int64
# of_those_inhabitants_18+            int64
# vehicles_overall                    int64
# cars_only                           int64
# vehicles_per_1000_inhabitants       int64
# cars_per_1000_inhabitants           int64
# geometry                         geometry
# dtype: object

# %%
df_registered_cars.head(6)
# Out:
#                    district                lor             Bezirksregion  \
# 0  Friedrichshain-Kreuzberg        Wrangelkiez      Südliche Luisenstadt
# 1  Friedrichshain-Kreuzberg     Stralauer Kiez  Frankfurter Allee Süd FK
# 2  Friedrichshain-Kreuzberg     Wassertorplatz   Südliche Friedrichstadt
# 3  Friedrichshain-Kreuzberg       Oranienplatz     Nördliche Luisenstadt
# 4  Friedrichshain-Kreuzberg       Mehringplatz   Südliche Friedrichstadt
# 5  Friedrichshain-Kreuzberg  Askanischer Platz   Südliche Friedrichstadt
#
#          Prognoseraum  lor size in m²  inhabitants_total  \
# 0       Kreuzberg Ost       526529.00              10979
# 1  Friedrichshain Ost      1354726.79               7752
# 2      Kreuzberg Nord       388873.74               5065
# 3       Kreuzberg Ost       480676.24               8847
# 4      Kreuzberg Nord      1036267.66              13833
# 5      Kreuzberg Nord       707419.20               6428
#
#    of_those_inhabitants_18+  vehicles_overall  cars_only  \
# 0                      9433              2375       1838
# 1                      6739              4904       3621
# 2                      4086              1113        908
# 3                      7537              2230       1694
# 4                     11037              3904       3499
# 5                      5395              2309       2113
#
#    vehicles_per_1000_inhabitants  cars_per_1000_inhabitants  \
# 0                            216                        167
# 1                            632                        467
# 2                            219                        179
# 3                            252                        191
# 4                            282                        252
# 5                            359                        328
#
#                                             geometry
# 0  POLYGON ((393564.961 5817715.429, 393969.009 5...
# 1  POLYGON ((394458.458 5817914.213, 394513.006 5...
# 2  POLYGON ((391133.382 5817632.388, 391157.070 5...
# 3  POLYGON ((392393.802 5818353.854, 392395.806 5...
# 4  POLYGON ((390442.484 5818691.844, 390468.602 5...
# 5  POLYGON ((389687.563 5818256.442, 389681.790 5...

# %%
kfz_lor_planungsraum_path = os.path.join("neukoelln", "kfz_lor_planungsraum.geojson") # parking_way, parking_area
df_kfz_lor_planungsraum = gpd.read_file(kfz_lor_planungsraum_path)
#Planungsraum = lor
df_kfz_lor_planungsraum = df_kfz_lor_planungsraum.rename(columns={"Bezirk": "district", "Planungsraum": "lor", "Flächengröße in m²": "lor size in m²", "Einwohner insgesamt": "inhabitants_total", "darunter 18 Jahre und älter": "of_those_inhabitants_18+", "Kraftfahrzeuge insgesamt": "vehicles_overall", "darunter Pkw": "cars_only", "Kfz pro 1000 EW": "vehicles_per_1000_inhabitants", "Pkw pro 1000 EW": "cars_per_1000_inhabitants"})
df_kfz_lor_planungsraum.dtypes
# Out:
# Schlüssel                          object
# district                           object
# lor                                object
# Bezirksregion                      object
# Prognoseraum                       object
# lor size in m²                    float64
# inhabitants_total                   int64
# of_those_inhabitants_18+            int64
# vehicles_overall                    int64
# cars_only                           int64
# vehicles_per_1000_inhabitants       int64
# cars_per_1000_inhabitants           int64
# geometry                         geometry
# dtype: object

# %%
df_kfz_lor_planungsraum.head(6)
# Out:
#   Schlüssel             district              lor  Bezirksregion Prognoseraum  \
# 0  10010310  Marzahn-Hellersdorf      Alt-Marzahn    Marzahn Süd      Marzahn
# 1  10010101  Marzahn-Hellersdorf     Marzahn West   Marzahn Nord      Marzahn
# 2  10010206  Marzahn-Hellersdorf   Ringkolonnaden  Marzahn Mitte      Marzahn
# 3  10010204  Marzahn-Hellersdorf   Wuhletalstraße  Marzahn Mitte      Marzahn
# 4  10010102  Marzahn-Hellersdorf   Havemannstraße   Marzahn Nord      Marzahn
# 5  10010311  Marzahn-Hellersdorf  Landsberger Tor    Marzahn Süd      Marzahn
#
#    lor size in m²  inhabitants_total  of_those_inhabitants_18+  \
# 0      2238368.26              18290                     15454
# 1       694985.47               5676                      4528
# 2      1486009.41              17341                     14565
# 3       845563.37              10622                      8488
# 4      1898742.52              18508                     14659
# 5      1608201.44               3694                      3028
#
#    vehicles_overall  cars_only  vehicles_per_1000_inhabitants  \
# 0              7132       6457                            389
# 1              1959       1783                            345
# 2              5947       5387                            342
# 3              3439       3174                            323
# 4              5514       5090                            297
# 5              1634       1469                            442
#
#    cars_per_1000_inhabitants  \
# 0                        353
# 1                        314
# 2                        310
# 3                        298
# 4                        275
# 5                        397
#
#                                             geometry
# 0  POLYGON ((13.53692 52.53470, 13.53739 52.53467...
# 1  POLYGON ((13.54462 52.56693, 13.54471 52.56694...
# 2  POLYGON ((13.54802 52.55098, 13.54883 52.55074...
# 3  POLYGON ((13.55390 52.55776, 13.55476 52.55748...
# 4  POLYGON ((13.55825 52.56300, 13.55882 52.56279...
# 5  POLYGON ((13.58610 52.54937, 13.58616 52.54943...

# %%
#df_district_neukölln = df_kfz_lor_planungsraum.query("Bezirk == 'Neukölln'")
df_district_neukölln = df_kfz_lor_planungsraum.query("district == 'Neukölln'")
df_district_neukölln.dtypes
# Out:
# Schlüssel                          object
# district                           object
# lor                                object
# Bezirksregion                      object
# Prognoseraum                       object
# lor size in m²                    float64
# inhabitants_total                   int64
# of_those_inhabitants_18+            int64
# vehicles_overall                    int64
# cars_only                           int64
# vehicles_per_1000_inhabitants       int64
# cars_per_1000_inhabitants           int64
# geometry                         geometry
# dtype: object

# %%
df_district_neukölln.sample(6)
# Out:
#     Schlüssel  district                    lor             Bezirksregion  \
# 212  08010117  Neukölln      Schillerpromenade         Schillerpromenade
# 120  08030831  Neukölln       Gropiusstadt Ost              Gropiusstadt
# 121  08030830  Neukölln       Gropiusstadt Süd              Gropiusstadt
# 136  08020619  Neukölln    Buschkrugallee Nord                     Britz
# 218  08010406  Neukölln  Treptower Straße Nord                   Rixdorf
# 205  08010214  Neukölln        Glasower Straße  Neuköllner Mitte/Zentrum
#
#      Prognoseraum  lor size in m²  inhabitants_total  \
# 212      Neukölln       501547.32              15798
# 120  Gropiusstadt      1132631.37              17680
# 121  Gropiusstadt       676876.83               7279
# 136  Britz/Buckow      1845319.95              11702
# 218      Neukölln       430916.37               7073
# 205      Neukölln       589088.41               8570
#
#      of_those_inhabitants_18+  vehicles_overall  cars_only  \
# 212                     13690              2848       2328
# 120                     14381              5140       4705
# 121                      6333              2442       2195
# 136                      9387              4496       3634
# 218                      5675              1544       1291
# 205                      7272              2066       1643
#
#      vehicles_per_1000_inhabitants  cars_per_1000_inhabitants  \
# 212                            180                        147
# 120                            290                        266
# 121                            335                        301
# 136                            384                        310
# 218                            218                        182
# 205                            241                        191
#
#                                               geometry
# 212  POLYGON ((13.42483 52.48087, 13.42309 52.48068...
# 120  POLYGON ((13.46089 52.42075, 13.46146 52.42082...
# 121  POLYGON ((13.44543 52.42662, 13.44568 52.42635...
# 136  POLYGON ((13.43418 52.46275, 13.43428 52.46250...
# 218  POLYGON ((13.44468 52.48499, 13.44550 52.48456...
# 205  POLYGON ((13.43137 52.46780, 13.43159 52.46744...

# %%
parking_way_path = os.path.join("neukoelln", "parking_way.geojson") # parking_way, parking_area
df_parking_way = gpd.read_file(parking_way_path)
df_parking_way = df_parking_way.rename(columns = {"highway:name": "name", "source:capacity": "source_capacity"})
df_parking_way.dtypes
# Out:
# condition                 object
# parking                   object
# orientation               object
# condition:other           object
# position                  object
# condition:other:time      object
# source_capacity           object
# oneway_direction          object
# highway                   object
# name                      object
# maxstay                   object
# capacity                   int64
# osm-location              object
# osm_id                    object
# id                         int64
# length                   float64
# geometry                geometry
# dtype: object

# %%
df_parking_way.head(6)
# Out:
#   condition      parking    orientation condition:other     position  \
# 0      free  street_side  perpendicular            None  street_side
# 1      free  street_side       parallel            None  street_side
# 2      free  street_side       diagonal            None  street_side
# 3      free  street_side       diagonal            None  street_side
# 4      free  street_side  perpendicular              no  street_side
# 5      free  street_side  perpendicular              no  street_side
#
#       condition:other:time source_capacity oneway_direction        highway  \
# 0                     None             OSM             None    residential
# 1                     None       estimated             None    residential
# 2                     None             OSM             None       tertiary
# 3                     None             OSM             None       tertiary
# 4  Apr-Sep: We 14:00-18:00             OSM             None  living_street
# 5  Apr-Sep: We 14:00-18:00             OSM             None  living_street
#
#                     name maxstay  capacity osm-location         osm_id  id  \
# 0  Schaffhausener Straße    None        38     separate   way/37722270   1
# 1            Körtestraße    None         6     separate  way/851610744   2
# 2          Wiener Straße    None        40     separate  way/554762162   3
# 3          Wiener Straße    None         6     separate  way/554762163   4
# 4            Böckhstraße    None         3     separate  way/867318940   5
# 5            Böckhstraße    None         4     separate  way/867318940   6
#
#     length                                           geometry
# 0   90.389  LINESTRING (13.41520 52.46092, 13.41389 52.46107)
# 1   31.143  LINESTRING (13.41283 52.49142, 13.41240 52.49152)
# 2  111.645  LINESTRING (13.43235 52.49734, 13.43379 52.49685)
# 3   20.422  LINESTRING (13.43490 52.49647, 13.43516 52.49638)
# 4    6.762  LINESTRING (13.41570 52.49460, 13.41579 52.49458)
# 5    8.970  LINESTRING (13.41611 52.49450, 13.41623 52.49447)

# %%
parking_spots_columns = ["highway", "name", "parking", "orientation", "position", "capacity", "source_capacity", "geometry"]
df_parking_spots_kfz_neukölln = pd.concat([df_count_parking_spots_estimated_kfz[parking_spots_columns], df_parking_way[parking_spots_columns]], ignore_index=True)
df_parking_spots_kfz_neukölln.shape
# Out:
# (75296, 8)

# %%
lor_columns = ['district', 'lor', 'Bezirksregion', 'Prognoseraum', 'lor size in m²', 'inhabitants_total', 'of_those_inhabitants_18+', 'vehicles_overall', 'cars_only', 'vehicles_per_1000_inhabitants', 'cars_per_1000_inhabitants', 'geometry']
df_lor_kfz_neukölln = pd.concat([df_registered_cars[lor_columns], df_district_neukölln[lor_columns]], ignore_index=True)
df_lor_kfz_neukölln["lor_geometry"] = df_lor_kfz_neukölln["geometry"] 
df_lor_kfz_neukölln.shape
# Out:
# (66, 13)

# %%
# Make a spatial join
df_kfz_neukölln = gpd.sjoin(df_parking_spots_kfz_neukölln, df_lor_kfz_neukölln, how="inner", predicate="within")
df_kfz_neukölln.shape
# Out:
# (70172, 21)

# %%
df_kfz_neukölln.sample(6)
# Out:
#            highway                name parking    orientation   position  \
# 10251  residential        Ritterstraße    lane  perpendicular  on_street
# 5204   residential       Riemannstraße    lane       parallel  on_street
# 4984   residential    Johanniterstraße    lane       parallel  on_street
# 15551  residential  Gabriel-Max-Straße    lane       parallel  on_street
# 69689      service                None    lane  perpendicular  on_street
# 20295  residential       Virchowstraße    lane       parallel  on_street
#
#       capacity source_capacity                        geometry  index_right  \
# 10251       88       estimated  POINT (392214.723 5817942.002)            7
# 5204         6       estimated  POINT (390749.049 5816838.875)           18
# 4984        35       estimated  POINT (391351.237 5817428.359)           21
# 15551       20       estimated  POINT (395430.222 5819083.870)            9
# 69689       95       estimated  POINT (395562.120 5818100.636)            1
# 20295        8       estimated  POINT (394272.365 5820665.461)           17
#
#                        district  ...             Bezirksregion  \
# 10251  Friedrichshain-Kreuzberg  ...   Südliche Friedrichstadt
# 5204   Friedrichshain-Kreuzberg  ...      Tempelhofer Vorstadt
# 4984   Friedrichshain-Kreuzberg  ...      Tempelhofer Vorstadt
# 15551  Friedrichshain-Kreuzberg  ...  Frankfurter Allee Süd FK
# 69689  Friedrichshain-Kreuzberg  ...  Frankfurter Allee Süd FK
# 20295  Friedrichshain-Kreuzberg  ...      Karl-Marx-Allee Nord
#
#               Prognoseraum lor size in m²  inhabitants_total  \
# 10251       Kreuzberg Nord      796853.52              15234
# 5204         Kreuzberg Süd      976591.13              14964
# 4984         Kreuzberg Süd      922448.94              12562
# 15551   Friedrichshain Ost      832852.89              21584
# 69689   Friedrichshain Ost     1354726.79               7752
# 20295  Friedrichshain West      940904.43               5380
#
#        of_those_inhabitants_18+  vehicles_overall  cars_only  \
# 10251                     12261              4012       3452
# 5204                      12839              4082       3356
# 4984                      10730              3410       2766
# 15551                     18660              4431       3532
# 69689                      6739              4904       3621
# 20295                      4631              1664       1552
#
#        vehicles_per_1000_inhabitants  cars_per_1000_inhabitants  \
# 10251                            263                        226
# 5204                             272                        224
# 4984                             271                        220
# 15551                            205                        163
# 69689                            632                        467
# 20295                            309                        288
#
#                                             lor_geometry
# 10251  POLYGON ((391353.802 5817686.896, 391379.910 5...
# 5204   POLYGON ((390424.978 5816299.466, 390852.473 5...
# 4984   POLYGON ((390551.705 5817048.095, 390735.281 5...
# 15551  POLYGON ((394808.031 5818639.398, 394842.335 5...
# 69689  POLYGON ((394458.458 5817914.213, 394513.006 5...
# 20295  POLYGON ((392793.678 5820666.844, 392843.729 5...
#
# [6 rows x 21 columns]

# %%
df_kfz_neukölln.dtypes
# Out:
# highway                            object
# name                               object
# parking                            object
# orientation                        object
# position                           object
# capacity                           object
# source_capacity                    object
# geometry                         geometry
# index_right                         int64
# district                           object
# lor                                object
# Bezirksregion                      object
# Prognoseraum                       object
# lor size in m²                    float64
# inhabitants_total                   int64
# of_those_inhabitants_18+            int64
# vehicles_overall                    int64
# cars_only                           int64
# vehicles_per_1000_inhabitants       int64
# cars_per_1000_inhabitants           int64
# lor_geometry                     geometry
# dtype: object

# %%
# lor geometry
df_kfz_neukölln["lor_geometry"]
# Out:
# 0        POLYGON ((393240.766 5819958.699, 393249.411 5...
# 1        POLYGON ((393240.766 5819958.699, 393249.411 5...
# 2        POLYGON ((393240.766 5819958.699, 393249.411 5...
# 3        POLYGON ((393240.766 5819958.699, 393249.411 5...
# 4        POLYGON ((393240.766 5819958.699, 393249.411 5...
#                                ...
# 74282    POLYGON ((13.452 52.481, 13.452 52.481, 13.452...
# 74283    POLYGON ((13.452 52.481, 13.452 52.481, 13.452...
# 74509    POLYGON ((13.452 52.481, 13.452 52.481, 13.452...
# 74743    POLYGON ((13.452 52.481, 13.452 52.481, 13.452...
# 74744    POLYGON ((13.452 52.481, 13.452 52.481, 13.452...
# Name: lor_geometry, Length: 70172, dtype: geometry

# %%
# parking spots geometry
df_kfz_neukölln["geometry"]
# Out:
# 0                           POINT (393464.636 5820319.350)
# 1                           POINT (393465.659 5820324.449)
# 2                           POINT (393467.819 5820340.710)
# 3                           POINT (393468.221 5820345.894)
# 4                           POINT (393468.623 5820351.079)
#                                ...
# 74282            LINESTRING (13.453 52.479, 13.454 52.479)
# 74283    LINESTRING (13.454 52.480, 13.454 52.480, 13.4...
# 74509            LINESTRING (13.451 52.480, 13.451 52.480)
# 74743    LINESTRING (13.454 52.480, 13.454 52.480, 13.4...
# 74744    LINESTRING (13.455 52.479, 13.455 52.479, 13.4...
# Name: geometry, Length: 70172, dtype: geometry

# %%
# Create plot 1
ax = df_kfz_neukölln.query("district == 'Friedrichshain-Kreuzberg'")["lor_geometry"].plot(facecolor='gray', figsize=(14, 14))
df_kfz_neukölln.query("district == 'Friedrichshain-Kreuzberg'")["geometry"].plot(ax=ax, facecolor='blue', figsize=(14, 14))
# Out:
# <AxesSubplot:>

# %%
# Create plot 2
ax = df_kfz_neukölln.query("district == 'Neukölln'")["lor_geometry"].plot(facecolor='gray', figsize=(14, 14))
df_kfz_neukölln.query("district == 'Neukölln'")["geometry"].plot(ax=ax, facecolor='blue', figsize=(14, 14))
# Out:
# <AxesSubplot:>

# %%
# save to a file for further data preparation, modeling and other purposes
#kfz_neukölln_path = os.path.join("kfz_neukölln.geojson")
#df_kfz_neukölln.to_file(kfz_neukölln_path, driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_120635/1480909747.py in <module>
#       1 # save to a file for further data preparation, modeling and other purposes
#       2 kfz_neukölln_path = os.path.join("kfz_neukölln.geojson")
# ----> 3 df_kfz_neukölln.to_file(kfz_neukölln_path, driver='GeoJSON')
#
# ~/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1112         from geopandas.io.file import _to_file
#    1113
# -> 1114         _to_file(self, filename, driver, schema, index, **kwargs)
#    1115
#    1116     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# ~/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     365         df = df.reset_index(drop=False)
#     366     if schema is None:
# --> 367         schema = infer_schema(df)
#     368     if crs:
#     369         crs = pyproj.CRS.from_user_input(crs)
#
# ~/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/io/file.py in infer_schema(df)
#     418
#     419     properties = OrderedDict(
# --> 420         [
#     421             (col, convert_type(col, _type))
#     422             for col, _type in zip(df.columns, df.dtypes)
#
# ~/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/io/file.py in <listcomp>(.0)
#     419     properties = OrderedDict(
#     420         [
# --> 421             (col, convert_type(col, _type))
#     422             for col, _type in zip(df.columns, df.dtypes)
#     423             if col != df._geometry_column_name
#
# ~/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/io/file.py in convert_type(column, in_type)
#     412             out_type = types[str(in_type)]
#     413         else:
# --> 414             out_type = type(np.zeros(1, in_type).item()).__name__
#     415         if out_type == "long":
#     416             out_type = "int"
#
# TypeError: Cannot interpret '<geopandas.array.GeometryDtype object at 0x7f16f4edcdf0>' as a data type
